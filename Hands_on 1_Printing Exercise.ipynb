# %% [markdown]
# ## MY FIRST PRACTICE

# %%
# This is a code about me learning python
print("Hello world!")
print("My name is Latifat Oseni.")
print("I am learning python.")
print("Python is Exciting!")
# Out:
# Hello world!
# My name is Latifat Oseni.
# I am learning python.
# Python is Exciting!

# %%
# This is a code about my favourite things to do
print("My favourite food is Bread with Beans.")
print("My favourite movie is All Americans.")
print("My favourite sport is Football.")
print("My favourite colour is Blue.")
# Out:
# My favourite food is Bread with Beans.
# My favourite movie is All Americans.
# My favourite sport is Football.
# My favourite colour is Blue.

# %%
# This is a code for python calculator
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10// 3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %%
# Displaying programming Language
print("Python")
print("Programming")
print("Lesson one")
# Out:
# Python
# Programming
# Lesson one

# %%
# Python program that prints my name
print("My name is Latifat Oseni.")
# Out:
# My name is Latifat Oseni.

# %%
#Python code that prints my dream career
print("I want to be a Supply Chain and Operations Manager.")
# Out:
# I want to be a Supply Chain and Operations Manager.

# %%
#Python code that prints my country
print("I am from Nigeria.")
# Out:
# I am from Nigeria.

# %%
#Python code that prints my aggregation
print(25 + 75)
print(40 // 6)
print(8**2)
# Out:
# 100
# 6
# 64
