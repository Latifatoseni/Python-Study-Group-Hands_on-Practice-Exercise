# %% [markdown]
# ##  1. Creating Variables

# %%
#Number One
# Python student's information.
student_name = "Latifat"
student_age = 27
student_country = "Nigeria"

print("my name is", student_name)
print("I am", student_age,"years old")
print("I am from", student_country)
# Out:
# my name is Latifat
# I am 27 years old
# I am from Nigeria

# %% [markdown]
# ## 2. Salary Calculation

# %%
# Number Two
# Calculation of an employee's Total salary inclusive of his bonus.
basic_salary = 180000
bonus = 35000
total_salary = basic_salary + bonus
print("His total salary is:", total_salary, "naira")
# Out:
# His total salary is: 215000 naira

# %% [markdown]
# ## 3. User Input

# %%
# Number Three
# Creating a User friendly interface using the input function.
user_name = input("Enter your name:")
print("Hello!,", user_name)
# Out:
# Enter your name: Latifat
# Hello!, Latifat

# %%
favourite_language = input("Enter your favourite programming Language:")
print("Your Favourite programming language is", favourite_language)
# Out:
# Enter your favourite programming Language: Python
# Your Favourite programming language is Python

# %% [markdown]
# ## 4. Working with Data Types

# %%
# Number Four
# Determination of various data types with generated variables.

a = 25
b = 22.5
goal= "Finally learning python programming"
my_goal = True

print(type(a))
print(type(b))
print(type(goal))
print(type(my_goal))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## 5. Dynamic Typing

# %%
# Number Five
# Trying out variable re-assignment
my_data = 50

# Before
print(type(my_data))

my_data = "God is the greatest"

# After
print(type(my_data))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## Mini Project

# %%
name = input("Enter your name:")
age = input("Enter your age")
course = input("Enter your course")
country = input("Enter your country")

print("STUDENT INFORMATION CARD")
print("Name:",name)
print("Age:", age)
print("Course:", course)
print("Country:", country)
# Out:
# Enter your name: Latifat
# Enter your age 27
# Enter your course Python programming
# Enter your country Nigeria
# STUDENT INFORMATION CARD
# Name: Latifat
# Age: 27
# Course: Python programming
# Country: Nigeria

# %% [markdown]
#  ## Data Type of information card

# %%
print(type(name))
print(type(age))
print(type(course))
print(type(country))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
name = input("Enter your name:")
age = int(input("Enter your age"))
course = input("Enter your course")
country = input("Enter your country")

print("STUDENT INFORMATION CARD")
print("Name:",name)
print("Age:", age)
print("Course:", course)
print("Country:", country)
# Out:
# Enter your name: Latifat
# Enter your age 27
# Enter your course Python
# Enter your country Nigeria
# STUDENT INFORMATION CARD
# Name: Latifat
# Age: 27
# Course: Python
# Country: Nigeria

# %%
# After data type conversion
print(type(name))
print(type(age))
print(type(course))
print(type(country))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
