# %% [markdown]
# # Hands-on Exercise

# %% [markdown]
# ## Customer Registration

# %%
# Number One
# Create a customer profile

customer_name = "Name:"
email_address = "Email:"
phone_number = "Phone:"
country = "Country:"
occupation = "Occupation:"

print(customer_name)
print(email_address)
print(phone_number)
print(country)
print(occupation)
# Out:
# Name:
# Email:
# Phone:
# Country:
# Occupation:

# %% [markdown]
# ## Hospital Patient Record

# %%
# Number Two
# Create patient infomation display

patient_name = "Patient:"
doctor = "Doctor:"
diagnosis = "Diagnosis:"
blood_group = "Blood Group:"
hospital = "Hospital:"

print("PATIENT RECORD")
print(patient_name)
print(doctor)
print(diagnosis)
print(blood_group)
print(hospital)

#Bonus task
print()
print("Multiline Spring Display")
patient_record = """Patient:
Doctor:
Diagnosis:
Blood Group:
Hospital: """

print(patient_record)
# Out:
# PATIENT RECORD
# Patient:
# Doctor:
# Diagnosis:
# Blood Group:
# Hospital:
#
# Multiline Spring Display
# Patient:
# Doctor:
# Diagnosis:
# Blood Group:
# Hospital:

# %% [markdown]
# ## AI Prompt Builder

# %%
# Number Three
# Create a prompt for a new AI Model

prompt = """You are an AI Assistant.
Analyse customer feedback.
Identify common complaints.
provide recommendations
Generate a summary report
Note: AI assistant can make mistakes, hence, futher research may be required!"""
print(prompt)
# Out:
# You are an AI Assistant.
# Analyse customer feedback.
# Identify common complaints.
# provide recommendations
# Generate a summary report
# Note: AI assistant can make mistakes, hence, futher research may be required!

# %% [markdown]
# # Insight Retail Technologies Company

# %% [markdown]
# ## Customer Feedback Management system

# %%
# Customer feedback display

company_name = "Insight Retail Technology"
email = "Insightretail@gmail.com"
customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_rating = "5 Stars"
customer_review = """
---------------------------------------------------------------------
The product arrived on time, was easy to "install",
and 'exceeded my expectations'.
I would definitely recommend it to others.
"""

name = input("Enter your name:")
print("Hello", name)
print(f"""Welcome to your customer report feedback!
Check out a Customer's feedback Report.""")

print("=====================================================================")
print("                 CUSTOMER FEEDBACK REPORT          "                  )
print("=====================================================================")
print("Customer Name:", customer_name)
print("Product Name:", product_name)
print("Product Category:", product_category)
print("Customer Rating:", customer_rating)
print("Customer Review:", customer_review)
print("=====================================================================")
print("Thank you for your feeback!")
print("=====================================================================")
print(f"Company's Name: {company_name}")
print(f"Support Email: {email}")
# Out:
# Enter your name: Latifat
# Hello Latifat
# Welcome to your customer report feedback!
# Check out a Customer's feedback Report.
# ...
#                  CUSTOMER FEEDBACK REPORT
# ...
# Customer Name: Sarah Johnson
# Product Name: Wireless Mouse
# Product Category: Computer Accessories
# Customer Rating: 5 Stars
# Customer Review:
# ---------------------------------------------------------------------
# The product arrived on time, was easy to "install",
# and 'exceeded my expectations'.
# I would definitely recommend it to others.
#
# ...
# Thank you for your feeback!
# ...
# Company's Name: Insight Retail Technology
# Support Email: Insightretail@gmail.com
