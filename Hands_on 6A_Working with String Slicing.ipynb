# %% [markdown]
# # Working With Strings

# %% [markdown]
# ## Patient Registration System

# %%
# Number one
# Create a professional patient registration card

first_name = "Grace"
last_name = "Johnson"
age = 34
blood_group =  "O+"
department = "Cardiology"
patient_name = first_name + " " + last_name


print(f"""==============CAREPLUS HOSPAITAL==============
Patient Name: {patient_name}
Age: {age} Years.
Blood Group: {blood_group}.
Department: {department}.
==============================================""")

# Bonus Challenge
print("") # prints a blank line
print("Patient Name: {} {}" .format(first_name.upper(), last_name.upper()))
print("Age: {}" .format(age))
print("Blood Group: {}" .format(blood_group))
print("Department: {}" .format(department))
# Out:
# ==============CAREPLUS HOSPAITAL==============
# Patient Name: Grace Johnson
# Age: 34 Years.
# Blood Group: O+.
# Department: Cardiology.
# ...
#
# Patient Name: GRACE JOHNSON
# Age: 34
# Blood Group: O+
# Department: Cardiology

# %% [markdown]
# ## Fraud Detection Log Analyzer

# %%
# Number Two
# Clean and Inspect a bank record logged

bank_record = "     LOGIN SUCCESSFUL FROM ATM-045 ON 2026-07-25     "

print("Original log:", bank_record)
print("Cleaned Log:", bank_record.strip())
print("Placed Lowercase:", cleaned_log.lower())
print("Position:" , cleaned_log.find("SUCCESSFUL"))
print("Updated log:", cleaned_log.replace("SUCCESSFUL","VERIFIED"))

print("") # prints a blank line
cleaned_log = bank_record.strip()
print("Use of Split:", bank_record.split())
print("Number of characters before Cleaning:", len(bank_record))
print("Number of characters after Cleaning:", len(cleaned_log))
print("Number of words:", len(bank_record.split()))
# Out:
# Original log:      LOGIN SUCCESSFUL FROM ATM-045 ON 2026-07-25
# Cleaned Log: LOGIN SUCCESSFUL FROM ATM-045 ON 2026-07-25
# Placed Lowercase: login successful from atm-045 on 2026-07-25
# Position: 6
# Updated log: LOGIN VERIFIED FROM ATM-045 ON 2026-07-25
#
# Use of Split: ['LOGIN', 'SUCCESSFUL', 'FROM', 'ATM-045', 'ON', '2026-07-25']
# Number of characters before Cleaning: 53
# Number of characters after Cleaning: 43
# Number of words: 6

# %% [markdown]
# ## Movie Recommendation Search Engine

# %%
# Number Three
# Word extraction from an online streaming platform

new_movie = input("Enter movie title:")
print("First Character:", new_movie[0])
print("Last Character:", new_movie[-1])
print("First Word:", new_movie[0:3])
print("Last Word:", new_movie[-7:])
print("Starting point:", new_movie.find("Returns"))
print(new_movie.split())

print()
# Bonus Challenge
print("Total Number of words:", len(new_movie.split()))
print("Number of Characters", len(new_movie))
print(new_movie.title())
# Out:
# Enter movie title: The last Kingdom Returns
# First Character: T
# Last Character: s
# First Word: The
# Last Word: Returns
# Starting point: 17
# ['The', 'last', 'Kingdom', 'Returns']
#
# Total Number of words: 4
# Number of Characters 24
# The Last Kingdom Returns
