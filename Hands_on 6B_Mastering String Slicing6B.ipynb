# %% [markdown]
# # Mastering String Slicing

# %% [markdown]
# ## Employee Record Information Extractor

# %%
# Number One 
# Extraction of Employee Record

employee_record = "EMP-HR-2026-004512"
print("Employee Prefix:", employee_record[:3])
print("Department:", employee_record[4:6])
print("Employment Year:", employee_record[7:11])
print("Employee Number:", employee_record[12:])
print("First 10 Character:", employee_record[:10])
print("Last 6 Character:", employee_record[-6:])
print("Every Second Character:", employee_record[::2])
print("Every Third Character:", employee_record[::3])
print("Reverse Character:", employee_record[::-1])
# Out:
# Employee Prefix: EMP
# Department: HR
# Employment Year: 2026
# Employee Number: 004512
# First 10 Character: EMP-HR-202
# Last 6 Character: 004512
# Every Second Character: EPH-06041
# Every Third Character: E--205
# Reverse Character: 215400-6202-RH-PME

# %% [markdown]
# ## Bank Card Security Formatter

# %%
# Number Two
# Extract portion of card number for Card Validation

card_number = "5489123476549876"

print("First 4 digits:", card_number[:4])
print("Last 4 digits:", card_number[-4:])
print("Median:", len(card_number)//2)
print("Middle 8 digits:", card_number[4:12])
print("Every 2nd digits:", card_number[::2])
print("Every 3rd digits:", card_number[::3])
print("Reverse Card:", card_number[::-1])
print("Reverse Last 8 digit:", card_number[16:7:-1])
print("Bank Card: **** **** ****", card_number[-4:])
# Out:
# First 4 digits: 5489
# Last 4 digits: 9876
# Median: 8
# Middle 8 digits: 12347654
# Every 2nd digits: 58137597
# Every 3rd digits: 593696
# Reverse Card: 6789456743219845
# Reverse Last 8 digit: 67894567
# Bank Card: **** **** **** 9876

# %% [markdown]
# ## Customer Information Processor

# %%
# Number Three
# Extract Customer record for documentation purpose


customer_record = "CUS-LAG-2026-000451"

print(" Customer Prefix:", customer_record[:3])
print(" City Code:", customer_record[4:7])
print(" Registration Year:", customer_record[8:12])
print(" Customer Number:", customer_record[-6:])
print(" First 8 characters :", customer_record[:8])
print(" Last 5 characters :", customer_record[-5:])
print(" Every second character :", customer_record[::2])
print(" Every Third character :", customer_record[::3])
print(" Record in Reverse :", customer_record[::-1])
# Out:
#  Customer Prefix: CUS
#  City Code: LAG
#  Registration Year: 2026
#  Customer Number: 000451
#  First 8 characters : CUS-LAG-
#  Last 5 characters : 00451
#  Every second character : CSLG22-041
#  Every Third character : C-G0-01
#  Record in Reverse : 154000-6202-GAL-SUC

# %%
# Number Three ii

customer_name = "Christopher Johnson"
print(" First Name:", customer_name[:11])
print(" Last Name:", customer_name[-7:])
print(" First 5 letters:", customer_name[:5])
print(" Last 7 letters: ", customer_name[-7:])
print(" Reverse Names:", customer_name[::-1])
# Out:
#  First Name: Christopher
#  Last Name: Johnson
#  First 5 letters: Chris
#  Last 7 letters:  Johnson
#  Reverse Names: nosnhoJ rehpotsirhC
